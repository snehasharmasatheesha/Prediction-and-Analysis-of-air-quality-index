# %%
# import bamboolib as bam 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from capstone_group_sneha_and_pranay import *

# %%
data_url = 'https://github.com/pranay8297/deep-learning-projects/blob/master/city_day.csv?raw=true'
y=pd.read_csv(data_url, header=0)

# %%
y = y.loc[~(y['AQI'].isna())]
y = y.loc[~(y['PM10'].isna())]
y = y.loc[~(y['Benzene'].isna())]
y = y.loc[~(y['NH3'].isna())]
y = y.loc[~(y['NOx']).isna()]
y = y.loc[~(y['CO']).isna()]
y = y.loc[~(y['Benzene']).isna()]

y = y.drop(columns=['Xylene'])
y = y.drop(columns=['Toluene'])

# %%
y
# Out:
#                 City        Date  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 2010          Aizawl  2020-03-12  31.21  38.66  7.20   1.27  10.65  25.63
# 2011          Aizawl  2020-03-13  38.39  46.68  7.19   0.91  10.37  29.16
# 2012          Aizawl  2020-03-14  43.23  50.83  7.14   1.07  10.48  28.95
# 2013          Aizawl  2020-03-15  33.82  41.03  7.09   0.36   9.73  28.41
# 2014          Aizawl  2020-03-16  27.14  35.04  5.63   2.32   8.09  23.98
# ...              ...         ...    ...    ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63  32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03
#
#          CO    SO2     O3  Benzene   AQI    AQI_Bucket
# ...

# %%
# def boxplot(feature):
#     """
#     function to plot a boxplot
#     Parameters
#     -------------
#     feature: 
#         a pandas data frame object on which you want to plot box plot of
#     -------------
#     Return
#         plot object - contains a box plot
#     """
#     return sns.boxplot(feature)

# def distributionPlot(feature):
#     """
#     function to plot a distribution plot
#     Parameters
#     -------------
#     feature: 
#         a pandas data frame object on which you want to plot box plot of
#     -------------
#     Return
#         plot object - contains a distribution plot plot
#     """
#     return sns.distplot(feature)

# %%
boxplot(y['PM2.5'])
# Out:
# <AxesSubplot:xlabel='PM2.5'>

# %%
distributionPlot(y['PM2.5'])
# Out:
# <AxesSubplot:xlabel='PM2.5'>

# %%
# def ReplaceWithMedian(feature,df):
#     """
#     function to replace all missing values with the median off the distribution
#     Parameters
#     -------------
#     feature: 
#         Feature on which you want to perform this operation
#     df: 
#         Data frame which contains all the data
#     -------------
#     Return
#     DataFrame:
#         the dataframe where all the missing values of the varible feature are filled with median values
#     """
#     return df[feature].fillna(df[feature].median(),inplace=True)

# %%
ReplaceWithMedian('PM2.5',y)

# %%
boxplot(y['NO'])
# Out:
# <AxesSubplot:xlabel='NO'>

# %%
distributionPlot(y['NO'])
# Out:
# <AxesSubplot:xlabel='NO'>

# %%
ReplaceWithMedian('NO',y)

# %%
sns.boxplot(y['NO2'],showmeans=True)
# Out:
# <AxesSubplot:xlabel='NO2'>

# %%
distributionPlot(y['NO2'])
# Out:
# <AxesSubplot:xlabel='NO2'>

# %%
ReplaceWithMedian('NO2',y)

# %%
distributionPlot(y['NOx'])
# Out:
# <AxesSubplot:xlabel='NOx'>

# %%
boxplot(y['NOx'])
# Out:
# <AxesSubplot:xlabel='NOx'>

# %%
ReplaceWithMedian('NOx',y)

# %%
boxplot(y['CO'])
# Out:
# <AxesSubplot:xlabel='CO'>

# %%
distributionPlot(y['CO'])
# Out:
# <AxesSubplot:xlabel='CO'>

# %%
ReplaceWithMedian('CO',y)

# %%
boxplot(y['SO2'])
# Out:
# <AxesSubplot:xlabel='SO2'>

# %%
distributionPlot(y['SO2'])
# Out:
# <AxesSubplot:xlabel='SO2'>

# %%
ReplaceWithMedian('SO2',y)

# %%
boxplot(y['O3'])
# Out:
# <AxesSubplot:xlabel='O3'>

# %%
distributionPlot(y['O3'])
# Out:
# <AxesSubplot:xlabel='O3'>

# %%
ReplaceWithMedian('O3',y)

# %%
# Removing 0 values for log and other functions
for i in ['Benzene', 'CO', 'NOx']:
    y[i] = y[i] + y[i].std() * (1e-03)

# %%
# def data_transform(df, feature_list):
#     """
#     This function will apply square root followed by log function to transform the data
#     -------------
#     Parameters 
#     df: 
#         The dataframe to which you want to apply this transforms on
#     feature_list:
#         List of features to which this particular transofrms should be applied to
#     -------------
#     Return
#     DataFrame:
#         Transformed data frame
#     """
#     df[feature_list] = np.sqrt(df[feature_list])
#     df[feature_list] = np.log(df[feature_list])
#     return df

# %%
y1 = y.copy()
y1 = data_transform(y1, ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO','SO2', 'O3', 'Benzene', 'AQI'])

# %%
distributionPlot(y1['PM2.5'])
# Out:
# <AxesSubplot:xlabel='PM2.5'>

# %%
distributionPlot(y1['NO'])
# Out:
# <AxesSubplot:xlabel='NO'>

# %%
boxplot(y1['PM2.5'])
# Out:
# <AxesSubplot:xlabel='PM2.5'>

# %%
# #Method 1 to remove outliers
# def remove_outliers(feature,y1):
#     """
#     function to import data from a json file
#     Parameters
#     -------------
#     filename: 
#         name of the file  
#     Return
#     -------------
#     Series or DataFrame:
#         The contents of the file are returned in the Series or DataFrame format
#     """
#     iqr_pm25 = y1[feature].quantile(0.75) - y1[feature].quantile(0.25)
#     low = y1[feature].quantile(0.25) - 1.5*iqr_pm25
#     upp =  y1[feature].quantile(0.75) + 1.5*iqr_pm25
#     std_dev=y1[feature].std()
#     return y1.loc[~((y1[feature]<low) | (y1[feature]>upp))]

# %%
# def outlier_count(df, feature_list):
#     """
#     function to import data from a json file
#     Parameters
#     -------------
#     filename: 
#         name of the file  
#     Return
#     -------------
#     Series or DataFrame:
#         The contents of the file are returned in the Series or DataFrame format
#     """
#     iqr = df[feature_list].quantile(0.75) - df[feature_list].quantile(0.25)
#     low = df[feature_list].quantile(0.25) - 1.5*iqr
#     up =  df[feature_list].quantile(0.75) + 1.5*iqr
#     return len(df.loc[(df[feature_list]<low) | (df[feature_list]>up)])

# %%
for i in ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO','SO2', 'O3', 'Benzene', 'AQI']:
    print(f"{i} : {outlier_count(y1, i)}")
# Out:
# PM2.5 : 116
# PM10 : 123
# NO : 167
# NO2 : 335
# NOx : 674
# NH3 : 247
# CO : 929
# SO2 : 274
# O3 : 414
# Benzene : 37
# AQI : 100

# %%
from pdb import set_trace

# %%
#splitting date into day, month and year
y1['date'] = pd.to_datetime(y1['Date'])
y1['day'] = pd.DatetimeIndex(y1['Date']).day
y1['month'] = y1['date'].map(lambda x: x.month)
y1['year'] = y1['date'].map(lambda x: x.year)

# y1 = y1.drop(columns=['Date', 'date'])

# %%
y1 = y1.drop(columns=['date'])

# %%
import seaborn as sns
for_graph = y1.copy()
for_graph = for_graph.drop(columns = ['City', 'AQI_Bucket', 'month', 'year','day','AQI'])
ax = sns.boxplot(data=for_graph, linewidth = 1, orient = 'v')

# %%
from sklearn.model_selection import train_test_split

# %%
y1 = y1.drop(columns = ['day', 'month', 'year'])

# %%
y1 = y1.drop(columns = ['City'])
y1 = y1.drop(columns = ['Date'])

# %%
y2 = y1.copy()

# %%
reg_label = np.array(y1['AQI'])
class_label = np.array(y1['AQI_Bucket'])

# %%
reg_label
# Out:
# array([1.97562186, 2.04717228, 2.06356719, ..., 2.12424762, 2.10975385,
#        1.99449202])

# %%
list(y1.columns)
# Out:
# ['PM2.5',
#  'PM10',
#  'NO',
#  'NO2',
#  'NOx',
#  'NH3',
#  'CO',
#  'SO2',
#  'O3',
#  'Benzene',
#  'AQI',
#  'AQI_Bucket']

# %%
y1 = y1.drop(columns = ['AQI', 'AQI_Bucket'])

# %%
feature_list = list(y1.columns)
features = np.array(y1)

# %%
x_train, x_test, y_train, y_test = train_test_split(features, reg_label, test_size = 0.2, random_state = 42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (10455, 10) (2614, 10) (10455,) (2614,)

# %%
feature_list=['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene']
each_variable_features = {}

for i in range(len(feature_list)):
    f = feature_list[i]
    act_x = np.array(x_test)[:, i]
    each_variable_features[feature_list[i]] = x_test[:, i]

# %%
# from bokeh.plotting import figure, output_file, show
# from bokeh.io import output_file, show, output_notebook
# from bokeh.layouts import row, column

# # p = figure(width=200, height=200)

# # # add a circle renderer with a size, color, and alpha
# # p.circle(test_features[:, 0], test_labels, size=8, color="navy", alpha=0.9)
# # p.square(test_features[:, 0], predictions, size = 8, color = 'olive', alpha = 0.4)

# # show(p)

# def get_plot(x, ya, yp, xl):
#     p = figure(width=320, height=320, x_axis_label = xl, y_axis_label = 'AQI', title = f'{xl} and AQI Distribution')
#     p.circle(x, ya, size=8, color="navy", alpha=0.9, legend = 'Actual')
#     p.square(x, yp, size = 8, color = 'olive', alpha = 0.4, legend = 'Predictions')
#     p.legend.location = "top_left"
#     return p

# def get_grid(plots):
#     r1 = row(plots[0:5])
#     r2 = row(plots[5:10])
    
#     cols = column([r1, r2])
#     return cols

# %%
# y1=pd.get_dummies(y1, columns=['City'], drop_first=False, dummy_na=False)

# %%
# regression_data = y1.copy()
# regression_data = data_transform(regression_data,y1,['AQI'])
# regression_data = regression_data.drop(columns = ['AQI_Bucket'])

# %%
# dependent_features=regression_data[['AQI']]
# independent_features=regression_data.drop(['AQI'],axis=1)
# from sklearn.model_selection import train_test_split
# x_train, x_test,y_train, y_test = train_test_split(independent_features,dependent_features,test_size=0.20)

# %% [markdown]
# # Linear Regression

# %%
import statsmodels.api as sm

lr = sm.add_constant(x_train) 
lr_model = sm.OLS(y_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     5835.
# Date:                Thu, 17 Feb 2022   Prob (F-statistic):               0.00
# Time:                        18:10:37   Log-Likelihood:                 7459.0
# No. Observations:               10455   AIC:                        -1.490e+04
# Df Residuals:                   10444   BIC:                        -1.482e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7959      0.009     86.557      0.000       0.778       0.814
# ...

# %%
from sklearn import datasets, linear_model
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

lin_preds = regr.predict(x_test)

lin_errors = abs(np.exp(y_test) - np.exp(lin_preds))
lin_mape = np.mean(lin_errors / np.exp(y_test))
print(lin_mape)
print(f'Accuracy is : {1 - lin_mape}')
# Out:
# 0.09046092523475441
# Accuracy is : 0.9095390747652456

# %%
x_test.shape, x_train.shape
# Out:
# ((2614, 10), (10455, 10))

# %%
# def get_Confusion_matrix(matrix,class_names,model):
#     # Get and reshape confusion matrix data,
#     #matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
#     matrix = matrix
#     # Build the plot
#     plt.figure(figsize=(16,7))
#     sns.set(font_scale=1.4)
#     sns.heatmap(matrix, annot=True, annot_kws={'size':10},
#             cmap=plt.cm.Greens, linewidths=0.2)

#     # Add labels to the plot
#     tick_marks = np.arange(len(class_names))
#     tick_marks2 = tick_marks + 0.5
#     plt.xticks(tick_marks, class_names, rotation=25)
#     plt.yticks(tick_marks2, class_names, rotation=0)
#     plt.xlabel('Predicted label')
#     plt.ylabel('True label')
#     plt.title('Confusion Matrix for ' +model)
#     plt.show()

# %%
x_train, y_train
# Out:
# (array([[ 2.10122565,  2.32132932,  1.23447332, ...,  1.14221056,
#           1.53541987,  0.43758588],
#         [ 1.76552768,  1.87262989,  1.01473159, ...,  1.18930989,
#           1.56294148,  0.76728038],
#         [ 1.8931165 ,  2.51374621,  1.66628079, ...,  0.93048727,
#           1.42477488,  1.41599711],
#         ...,
#         [ 2.33814041,  2.76540851,  1.74077387, ...,  1.87132858,
#           1.83306123,  0.69055137],
#         [ 0.76843361,  1.27315764,  0.19602104, ...,  1.25642301,
#           1.78080705, -1.2673383 ],
#         [ 1.99328687,  2.38673867,  0.98564969, ...,  1.06232694,
#           1.84593748,  0.04733106]]),
#  array([2.49521629, 1.97562186, 2.4299062 , ..., 2.73613534, 1.89209482,
#         2.36809922]))

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(x_train, y_train);

# %%
predictions = rf.predict(x_test)
actual_y_pred = np.exp(predictions)
actual_y = np.exp(np.array(y_test))
errors = abs(actual_y_pred - actual_y)
score = rf.score(x_test, y_test)
mape = np.mean((errors / actual_y))
print(mape)
print(f'Accuracy is : {100 - 100*mape} \nModel Score: {score}')
# Out:
# 0.05635377480683486
# Accuracy is : 94.36462251931651
# Model Score: 0.928374232795783

# %%
classification_data = y1.copy()

# %%
# classification_data = classification_data.drop(columns = ['AQI'])
# dependent_features=classification_data[['AQI_Bucket']]
# independent_features=classification_data.drop(['AQI_Bucket'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,Y_train, Y_test = train_test_split(features,class_label,test_size=0.20)

# %%
# def feature_importance(importances,model_name):
#     feature_importance = np.array(importances)
#     feature_names = np.array(feature_list)

#     #Create a DataFrame using a Dictionary
#     data={'feature_names':feature_names,'feature_importance':feature_importance}
#     fi_df = pd.DataFrame(data)

#     #Sort the DataFrame in order decreasing feature importance
#     fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

#     #Define size of bar plot
#     plt.figure(figsize=(10,20))
#     #Plot Searborn bar chart
#     sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
#     #Add chart labels
#     plt.title(model_name + ' FEATURE IMPORTANCE')
#     plt.xlabel('FEATURE IMPORTANCE')
#     plt.ylabel('FEATURE NAMES')

# %% [markdown]
# # Classification Models

# %% [markdown]
# # Decision trees

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(criterion="entropy", random_state=42,max_depth=4, min_samples_leaf=5)   
dt_model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=5,
#                        random_state=42)

# %%
Z_predict = dt_model.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(Y_test,Z_predict)
# Out:
# 0.7781178270849273

# %%
Z_predict
abc = np.array(Y_test)
c = 0
for i in range(len(Z_predict)):
    if (Z_predict[i] != abc[i]):
        c += 1
print(c/len(abc))
# Out:
# 0.22188217291507267

# %%
#Confusion Matrix

from sklearn.metrics import classification_report, confusion_matrix
confusion_matrix=confusion_matrix(Y_test, Z_predict)
class_names = np.unique(Y_test)
get_Confusion_matrix(confusion_matrix,class_names,'Decision tree')
print(classification_report(Y_test, Z_predict))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.61      0.82      0.70       186
#     Moderate       0.80      0.84      0.82       996
#         Poor       0.71      0.60      0.65       245
# Satisfactory       0.81      0.76      0.79       959
#       Severe       0.91      0.68      0.78        62
#    Very Poor       0.75      0.76      0.75       166
#
#     accuracy                           0.78      2614
#    macro avg       0.77      0.74      0.75      2614
# weighted avg       0.78      0.78      0.78      2614

# %%
importances = dt_model.feature_importances_
feature_importance(importances,'Decision Trees', feature_list)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42,max_depth=4)   
rf_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(max_depth=4, random_state=42)

# %%
zrf_predict = rf_model.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(Y_test,zrf_predict)
# Out:
# 0.7750573833205815

# %%
#Confusion Matrix

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test, zrf_predict))
confusion_matrix=confusion_matrix(Y_test, zrf_predict)
class_names = np.unique(Y_test)
get_Confusion_matrix(confusion_matrix,class_names,'Random Forest')
print(classification_report(Y_test, zrf_predict))
# Out:
# [[ 54   2   0 130   0   0]
#  [  0 846  17 132   0   1]
#  [  0  93 138   3   0  11]
#  [  1 122   1 835   0   0]
#  [  0   3   1   0  29  29]
#  [  0   5  36   0   1 124]]
#               precision    recall  f1-score   support
#
#         Good       0.98      0.29      0.45       186
#     Moderate       0.79      0.85      0.82       996
#         Poor       0.72      0.56      0.63       245
# Satisfactory       0.76      0.87      0.81       959
#       Severe       0.97      0.47      0.63        62
#    Very Poor       0.75      0.75      0.75       166
#
#     accuracy                           0.78      2614
#    macro avg       0.83      0.63      0.68      2614
# weighted avg       0.79      0.78      0.76      2614

# %%
#Feature Importance
importances = rf_model.feature_importances_
feature_importance(importances,'Random Forest', feature_list)

# %%
"VISUALIZATIONS - FOR RF"
# Out:
# 'VISUALIZATIONS - FOR RF'

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
output_notebook()
plots = [get_plot(each_variable_features[i], np.exp(y_test), np.exp(predictions), i) for i in each_variable_features]
grid = get_grid(plots)
show(grid)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="66caa7d6-76a7-4763-a35d-97ae5c6abd9e" data-root-id="1705"></div>

# %%
#Feature Importance
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral10
from bokeh.plotting import figure

# output_file("colormapped_bars.html")
output_notebook()
importances = rf.feature_importances_

feature_importance = np.array(importances)

source = ColumnDataSource(data = dict(features_list = feature_list, feature_importances = feature_importance, color = ('#3288bd', '#99d594', '#e6f598', '#fee08b', '#fc8d59', '#d53e4f', '#3288bd', '#99d594', '#e6f598', '#fee08b')))

p = figure(x_range = feature_list, y_range=(0 , 0.8), height=250, title="Random Forest Featur Impotance",
           toolbar_location=None, tools="")

p.vbar(x='features_list', top='feature_importances', width=0.8, color='color', legend_field="features_list", source=source)

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2426">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1327f55d-9142-40e2-a674-d048b00089c8" data-root-id="2428"></div>

# %%
"VISUALIZATIONS - FOR Linear Regression"
# Out:
# 'VISUALIZATIONS - FOR Linear Regression'

# %%
output_notebook()
plots = [get_plot(each_variable_features[i], np.exp(y_test), np.exp(lin_preds), i) for i in each_variable_features]
grid = get_grid(plots)
show(grid)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2638">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="40dd1dcc-325b-4fd7-bd52-f102a527969e" data-root-id="3341"></div>

# %%
#Feature Importance
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral10
from bokeh.plotting import figure

# output_file("colormapped_bars.html")
output_notebook()
importances = regr.coef_

feature_importance = np.array(importances)

source = ColumnDataSource(data = dict(features_list = feature_list, feature_importances = feature_importance, color = ('#3288bd', '#99d594', '#e6f598', '#fee08b', '#fc8d59', '#d53e4f', '#3288bd', '#99d594', '#e6f598', '#fee08b')))

p = figure(x_range = feature_list, y_range=(0 , 0.5), height=250, title="Random Forest Featur Impotance",
           toolbar_location=None, tools="")

p.vbar(x='features_list', top='feature_importances', width=0.8, color='color', legend_field="features_list", source=source)

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4191">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="67dfc96f-d133-4092-a8dd-e683b1c5d7e5" data-root-id="4193"></div>

# %%
"Data Distribution Visualizations"
# Out:
# 'Data Distribution Visualizations'

# %%
from bokeh.plotting import figure, output_file, show

p = figure(width=800, height=800)

# add a circle renderer with a size, color, and alpha
p.circle(x_test[:, 0], y_test, color="navy", alpha=1.0, size = 5, legend = feature_list[0])
p.asterisk(x_test[:, 1], y_test, color="red", alpha=0.7, size = 5, legend = feature_list[1])
p.diamond_cross(x_test[:, 2], y_test, color="yellow", alpha=0.5, size = 5, legend = feature_list[2])
p.star(x_test[:, 3], y_test, color="black", alpha=0.3, size = 5, legend = feature_list[3])

p.legend.location = "top_left"

# show the results
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4648">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cf04791f-2e0e-438d-8af8-63425124e56d" data-root-id="4532"></div>

# %%
p = figure(width=800, height=800)

# add a circle renderer with a size, color, and alpha
p.circle(x_test[:, 4], y_test, color="navy", alpha=1.0, size = 5, legend = feature_list[0])
p.asterisk(x_test[:, 5], y_test, color="red", alpha=0.7, size = 5, legend = feature_list[1])
p.diamond_cross(x_test[:, 6], y_test, color="yellow", alpha=0.5, size = 5, legend = feature_list[2])
p.star(x_test[:, 7], y_test, color="black", alpha=0.3, size = 5, legend = feature_list[3])

p.legend.location = "top_left"

# show the results
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5125">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="db11dcae-09e4-4d57-9fc6-923798066dd1" data-root-id="5009"></div>

# %%
p = figure(width=800, height=800)

# add a circle renderer with a size, color, and alpha
p.circle(x_test[:, 8], y_test, color="navy", alpha=1.0, size = 5, legend = feature_list[8])
p.asterisk(x_test[:, 9], y_test, color="red", alpha=0.7, size = 5, legend = feature_list[9])

# show the results
p.legend.location = "top_left"
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5573">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="78509f7c-be5f-480f-8f03-923cc804c7d0" data-root-id="5503"></div>
